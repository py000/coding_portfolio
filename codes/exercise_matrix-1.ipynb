# %% [markdown]
# # **Workshop of Matrix Exercise**
# ## (You shouldn't need AI to complete task 1-3)
#
# ---

# %% [markdown]
# ## I. Answer this questions directly without computing.

# %% [markdown]
# #### 1. Matrix inverse and identity matrix
# what is $A\cdot A^{-1}$
#
# what is $A^{-1}\cdot A$

# %%
I
I

# %% [markdown]
# #### 2. Matrix multiplication three
# Answer without calculation:
#
# Matrix \(A\) is an matrix with size $n\times m$:
#
# \begin{bmatrix}
# a_{11} & a_{12} & \ldots & a_{1m} \\
# a_{21} & a_{22} & \ldots & a_{2m} \\
# \vdots & \vdots & \ddots & \vdots \\
# a_{n1} & a_{n2} & \ldots & a_{nm} \\
# \end{bmatrix}
#
# Matrix \(B\) is an matrix with size $m\times k$:
# \begin{bmatrix}
# b_{11} & b_{12} & \ldots & b_{1k} \\
# b_{21} & b_{22} & \ldots & b_{2k} \\
# \vdots & \vdots & \ddots & \vdots \\
# b_{m1} & b_{m2} & \ldots & b_{mk} \\
# \end{bmatrix}
#
# What is the dimention of $A\cdot B$
#
# Does $A\cdot B$ equals to $B\cdot A$? (Assuming that $n=k$)
#
# Answer:
# No

# %% [markdown]
# #### 3. Matrix inverse and identity matrix
# If we have matrix $A$ and matrix $B$, what is
#
# $AB^{-1}AAAA^{-1}A^{-1}A^{-1}BB^{-1}BA^{-1}B = ?$

# %% [markdown]
# ## **PART II. Try to use numpy function to finish the following questions.**
# ### You can look up documents, but don't use AI to complete the exercise. The final answer is simple enough to type directly.
#
#
# Useful functions can be: (In the following, np stands for numpy and sp stands for scipy)
#
# Operator +/-
#
# np.transpose()
#
# X.T
#
# np.dot(X, Y)
#
# X.dot(Y)
#
# np.linalg.inv(X)
#
# sp.linalg.inv(X)

# %% [markdown]
# #### 1. Matrix addition and subtraction
#
# What is the result of:
# $$
# \begin{bmatrix}
# 1 & 2 & 3 \\
# 4 & 5 & 6 \\
# \end{bmatrix}
# +
# \begin{bmatrix}
# 7 & 8 & 9 \\
# 10 & 11 & 12 \\
# \end{bmatrix}=?
# $$
#
# $$
# \begin{bmatrix}
# 3 & 6 & 9 \\
# 1 & 5 & 7 \\
# \end{bmatrix}
# -
# \begin{bmatrix}
# 2 & 4 & 8 \\
# 2 & 1 & 2 \\
# \end{bmatrix}=?
# $$
# can you understand how the result is got without the numpy function?

# %%
import numpy as np

# %%
# Create two matrices (2D NumPy arrays)
matrix_A = np.array([[1, 2, 3],
                    [4, 5, 6]])

matrix_B = np.array([[7, 8, 9],
                    [10, 11, 12]])

matrix_A, matrix_B

# %%
# Perform matrix addition

# %%
# Create two matrices A and B
matrix_A = np.array([[3, 6, 9],
                    [1, 5, 7]])

matrix_B = np.array([[2, 4, 8],
                    [2, 1, 2]])

# %%
# Perform matrix subtraction

# %% [markdown]
# #### 2. Matrix transpose
#
# What is the transpose of:
# \begin{bmatrix}
# 1 & 22 & 333 \\
# 4444 & 55555 & 666666 \\
# 7 & 8 & 9 \\
# \end{bmatrix}
#
# and
#
# \begin{bmatrix}
# 1 & 2 & 3 \\
# 4 & 5 & 6 \\
# \end{bmatrix}

# %%
# Create a matrix (2D NumPy array)
matrix = np.array([[1, 22, 333],
                  [4444, 55555, 666666],
                  [7, 8, 9]])

# %%
# Perform matrix transposition

# %%
# Create a non-square matrix (2 rows and 3 columns)
matrix = np.array([[1, 2, 3],
                  [4, 5, 6]])

# %%
# Perform matrix transposition

# %% [markdown]
# #### 3. Matrix multiplication Q1
# What is:
#
# $\begin{bmatrix}
# 1 & 2 \\
# 3 & 4 \\
# \end{bmatrix}
# \cdot
# \begin{bmatrix}
# 5 & 6 \\
# 7 & 8 \\
# \end{bmatrix}=?$
#
# You can use numpy function to calculate this.

# %%
# Create two matrices (2D NumPy arrays)
matrix_A = np.array([[1, 2],
                    [3, 4]])

matrix_B = np.array([[5, 6],
                    [7, 8]])

# %%
# Perform matrix multiplication

# %% [markdown]
# #### 4. Matrix multiplication Q2
#
# If A = $\begin{bmatrix}
# 1 & 2 & 3 \\
# 4 & 5 & 6 \\
# 0 & 2 & 2 \\
# 9 & 8 & 7 \\
# \end{bmatrix}$
# and B =
# $\begin{bmatrix}
# 7 & 8 \\
# 9 & 10 \\
# 11 & 12 \\
# \end{bmatrix}$, $C = A \cdot B$, what is $C_{32}$?
#
# $C_{32}$ is the element of C in row 3 column 2.

# %%
# Create two matrices (2D NumPy arrays)
matrix_A = np.array([[1, 2, 3],
                    [4, 5, 6],
                    [0, 2, 2],
                    [9, 8, 7]])

matrix_B = np.array([[7, 8],
                    [9, 10],
                    [11, 12]])

# %% [markdown]
# #### 5. Matrix inverse
# Matrix inverse is expensive!
#
# What is the inverse of
# A =
# $\begin{bmatrix}
# 4&5&1\\
# 3&4&12\\
# 10&2&1\\
# \end{bmatrix}
# $
#
# You can use numpy or scipy function to calculate this.

# %%
# Create a 4x4 square matrix (2D NumPy array)
matrix_A = np.array([[4, 5, 1],
   [3, 4, 12],
   [10, 2, 1]])

# %%
# Calculate the inverse of the matrix

# %% [markdown]
# ## PART III. Write your own function to test the formula
#
# #### Verify the Change-of-Basis Formula for Linear Transformations
#
# We have learned that a linear transformation can have different matrix representations under different bases. These representations are related by the formula:
#
# $$
# T_{\text{new}} = P^{-1} T_{\text{std}} P
# $$
#
# where:
# - $T_{\text{std}}$: the matrix of the transformation under the **standard basis**
# - $P$: the **change-of-basis matrix** from the new basis to the old, whose columns are the new basis vectors expressed in the old basis
# - $T_{\text{new}}$: the matrix of the transformation under the **new basis**
#
# For any vector $v_{\text{new}}$ (the coordinates of a vector in the new basis), we should have:
#
# $$
# T_{\text{new}} P^{-1} \cdot v_{\text{std}} = P^{-1} T_{\text{std}} \cdot v_{\text{std}}
# $$
#
# here $v_{\text{std}}$ is the vector in the old stadard basis.
#
# ---
#
# #### Given
#
# 1. **Linear transformation**: counterclockwise rotation by 90°.
#    Its standard basis matrix is:
#    $$
#    T_{\text{std}} =
#    \begin{bmatrix}
#    0 & -1 \\
#    1 & 0
#    \end{bmatrix}
#    $$
#
# 2. **New basis**:
#    $$
#    f_1 = (1, 1), \quad f_2 = (1, -1)
#    $$
#
#    $$
#    T_{\text{new}} =
#    \begin{bmatrix}
#    0 & 1 \\
#    -1 & 0
#    \end{bmatrix}
#    $$
#
#    So the change-of-basis matrix is:
#    $$
#    P =
#    \begin{bmatrix}
#    1 & 1 \\
#    1 & -1
#    \end{bmatrix}
#    $$
#
# ### Task
#
# 1. Write a function `verify_basis_change(v_std)` that does the following:
#    - Takes as input a 2D vector `v_std`.
#    - Computes $T_{\text{new}} P^{-1} \cdot v_{\text{std}}$.
#    - Computes $P^{-1} T_{\text{std}} \cdot v_{\text{std}}$.
#    - Prints both results and checks if they are equal (up to default numerical precision).
# 2. Write another function `test_verify_basis_change()` that:
#    - Calls `verify_basis_change(v_std)` on at least **two different vectors**.
#    - Prints the results so you can confirm that the formula holds for multiple examples.

# %%
import numpy as np

# %%
def verify_basis_change(v_std):
    """
    Verify that T_new P v_std = P T_std v_std
    For two specific basis
    """
    ### Your task: define related matrices and compute left and right side of the formula
    # define matrix

    # Compute both sides
    left = ...
    right = ...
    
    # Print results
    print("T_new.dot(P_inv.dot(v_std))=\n", left)
    print("P_inv.dot(T_std.dot(v_std)) =\n", right)
    print("Are they equal?", np.allclose(left, right))
    print("-" * 40)

def test_verify_basis_change():
    """
    Test verify_basis_change with at least two vectors
    """
    vectors = [[1, 0], [0, 1], [2, 3]]  # example vectors in new basis
    for v in vectors:
        print(f"Testing v_new = {v}")
        verify_basis_change(v)
    
# Run the test
test_verify_basis_change()

# %% [markdown]
# ### Extra Task: General Rotation Matrix
#
# Now, instead of the 90° rotation, consider a rotation by an angle θ.
# The standard basis matrix of rotation is:
#
# $$
# T_{\text{std}}(\theta) =
# \begin{bmatrix}
# \cos\theta & -\sin\theta \\
# \sin\theta & \cos\theta
# \end{bmatrix}
# $$
#
# Change your code so that it works with the standard rotation matrix.
#
# Think about what would happen if we change to another new basis?

# %% [markdown]
# ## PART IV. Numerical Derivative Function (challenging, but interesting)
#
# In this task, you will write a function to compute the **numerical derivative** of a given function. You can implement this function in your own way. The simplest way is a first-order approximation (Taylor expansion), but you can use other methods.
#
# ### Your Task
#
# 1. Write a function `numerical_derivative(x, y)` that:
#    - Takes a 1D array `x` and a 1D array `y`
#    - Computes an approximation of the derivative of `y` at `x`
#    - Returns the numerical derivative and the corresponding `x` values
#
# 2. Test your function using the following code

# %%
import matplotlib.pyplot as plt

# %%
# Numerical derivative function (central difference)
def numerical_derivative(x, y):
    """
    Compute a numerical derivative of y with respect to x.
    
    Parameters:
    -----------
    x : array-like
        1D array of x values at which the function y is evaluated.
    y : array-like
        1D array of function values corresponding to x.
    
    Returns:
    --------
    x : ndarray
        It can be the same size as the input, but can also be a different size
    derivative : ndarray
        Numerical approximation of the derivative dy/dx at each x value.
        
    Notes:
    ------
    - This method handles non-uniform spacing in x (dx can vary).
    - There is no perfect answer to this question, you can try your own method.
    """
    
    ### Your task: finish the derivative function

    return x, div

# Test and plot
def test_derivative(f0,f1,x_vals):
    y_vals = f0(x_vals)
    x_num, y_num = numerical_derivative(x_vals, y_vals)
    y_true = f1(x_vals)
    
    plt.figure(figsize=(8,5))
    plt.plot(x_vals, y_true, label='Analytical derivative', color='blue')
    plt.plot(x_num, y_num, '--', label='Numerical derivative', color='red')
    plt.xlabel('x')
    plt.ylabel("f'(x)")
    plt.title("Comparison of Analytical and Numerical Derivatives")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# Example function
def f_power(x):
    return x**3 + 2*x**2

# Analytical derivative
def f1_power(x):
    return 3*x**2 + 4*x

x_vals = np.linspace(0, 4, 100)
test_derivative(f_power,f1_power,x_vals)

# %%
# Subtle test function
def f_subtle(x):
    return np.sin(5*x) * np.exp(-0.5*x)

# Analytical derivative
def f1_subtle(x):
    return 5*np.cos(5*x)*np.exp(-0.5*x) - 0.5*np.sin(5*x)*np.exp(-0.5*x)

x_vals = np.linspace(0, 4, 100)
test_derivative(f_subtle,f1_subtle,x_vals)

# %%
# Example function, which is an oscillating function
def f_xsin(x):
    return x * np.sin(x**2)

# Analytical derivative
def f1_xsin(x):
    return np.sin(x**2) + 2*x**2 * np.cos(x**2)

x_vals = np.linspace(0, 10, 100)
test_derivative(f_xsin,f1_xsin,x_vals)

# %% [markdown]
# ### **V. Self-learning:L Other properties of square matrices**

# %% [markdown]
# #### 1. Determinant:
#
# The determinant of a matrix is a scalar value that is calculated using the elements of a square matrix. It's commonly denoted as `det(A)`, `det A`, or `|A|`. The determinant helps us find the inverse of a matrix, tells us things about the matrix that are useful in systems of linear equations, calculus and more.
#
# Here's how you can calculate it:
# - For a 2x2 matrix (A = $\begin{bmatrix} a & b \\ c & d \end{bmatrix}$), the determinant is `ad - bc`.
# - For a 3x3 matrix (A = $\begin{bmatrix} a & b & c \\ d & e & f \\ g & h & i \end{bmatrix}$), the determinant is `a(ei - fh) - b(di - fg) + c(dh - eg)`.
# - The pattern continues for larger matrices: multiply `a` by the determinant of the matrix that is not in `a`'s row or column, continue like this across the whole row, but remember the `+ − + −` pattern.
#
# #### Determinants have several properties, including:
#    - If the determinant of a square matrix is **zero**, it indicates that the matrix is **singular** (not invertible).
#    - The determinant of the product of two matrices is equal to the product of their determinants: $\text{det}(AB) = \text{det}(A) \cdot \text{det}(B)$.
#    - The determinant of the transpose of a matrix is the same as the determinant of the original matrix: $\text{det}(A^T) = \text{det}(A)$.
#    - The determinant of the inverse of a matrix is the reciprocal of the determinant of the original matrix: $\text{det}(A^{-1}) = 1/\text{det}(A)$.
#
# The determinant characterizes some properties of the matrix and the linear map represented by the matrix. For example, if you apply the transformation represented by the matrix to a geometric shape, the area of the shape will be multiplied by the determinant of the matrix.

# %% [markdown]
# #### 2. Eigenvalues λ:
#    - Eigenvalues are scalars that represent how a linear transformation affects vectors in a matrix.
#    - For a square matrix $A$, an eigenvalue $\lambda$ is a scalar that, when multiplied by an eigenvector, results in the same vector: $A\mathbf{v} = \lambda\mathbf{v}$.
#    - Eigenvalues can be real or complex numbers.
#    - The characteristic equation, $|A - \lambda I| = 0$, where $I$ is the identity matrix, is used to find the eigenvalues of a matrix.
#
# #### 3. Eigenvectors $\mathbf{v}$:
#    - Eigenvectors are non-zero vectors associated with eigenvalues that remain in the same direction (up to scaling) after a linear transformation.
#    - For each eigenvalue $\lambda$, there can be multiple linearly independent eigenvectors.
#    - Eigenvectors can be normalized to have a magnitude of 1.
#
# #### 4. Diagonalization:
#    A diagonal matrix is a matrix in which the entries outside the main diagonal are all zero
#    - Diagonalization is the process of expressing a square matrix $A$ as a product of three matrices: $A = PDP^{-1}$, where $P$ is a matrix of eigenvectors and $D$ is a diagonal matrix of eigenvalues.
#    - Diagonalization simplifies matrix operations because it transforms the matrix into a diagonal form.
#    - Not all matrices are diagonalizable. A matrix is diagonalizable if and only if it has a full set of linearly independent eigenvectors.
#
# To diagonalize a matrix, you follow these steps:
# 1. Find the eigenvalues of the matrix by solving the characteristic equation.
# 2. For each eigenvalue, find the associated eigenvectors.
# 3. Form a matrix $P$ whose columns are the eigenvectors.
# 4. Form a diagonal matrix $D$ with the eigenvalues on the diagonal.
# 5. If $P$ has linearly independent columns (i.e., it's invertible), you can express $A$ as $A = PDP^{-1}$.

# %% [markdown]
# ###### Part of the above content is phrased with reference to the following website:
# ###### (1) Determinant of a Matrix - For Square Matrices with Examples - BYJU'S. https://byjus.com/maths/determinant-of-a-matrix/.
# ###### (2) Determinant - Wikipedia. https://en.wikipedia.org/wiki/Determinant.
# ###### (3) Determinant of a Matrix - Math is Fun. https://www.mathsisfun.com/algebra/matrix-determinant.html.
# ###### (4) What Really IS a Matrix Determinant? - Towards Data Science. https://towardsdatascience.com/what-really-is-a-matrix-determinant-89c09884164c.
# ###### (5) . https://bing.com/search?q=determinant+of+a+matrix+definition.
# ###### (6) Determinant of a Matrix: Definition, Calculation & Examples - Collegedunia. https://collegedunia.com/exams/determinant-of-a-matrix-mathematics-articleid-1391.
# ###### (7) undefined. https://math.libretexts.org/Bookshelves/Linear_Algebra/Interactive_Linear_Algebra_%28Margalit_and_Rabinoff%29/04%3A_Determinants/4.01%3A_Determinants-_Definition.
# ###### (8) undefined. https://textbooks.math.gatech.edu/ila/determinants-definitions-properties.html.
